# %%
from tkinter import *
from tkinter import ttk

# %%
#Definições de cores
co0 = '#FFFFFF'  # White
co1 = '#333333'  # Dark black
co2 = '#fcc058'  # Orange
co3 = '#38576b'  # Valor
co4 = '#3297a8'  # Blue
co5 = '#fff873'  # Amarela
co6 = '#fcc058'  # Orange
co7 = '#e85151'  # Red
co10 = '#fcfbf7'
fundo = '#3b3b3b'  # Black

# %%
# Definições de Janela da Aplicação
janela = Tk()
janela.title('Jogo da Velha')
janela.geometry('260x440')
janela.configure(bg=fundo)

# %%
# dividindo a janela em dois frames
frame_cima = Frame(janela, width=240, height=100, bg=co1, relief='raised')
frame_cima.grid(row=0, column=0, sticky=NW, padx=10, pady=15)

frame_baixo = Frame(janela, width=240, height=300, bg=fundo, relief='flat')
frame_baixo.grid(row=1, column=0, sticky=NW, padx=10, pady=15)

# %%
# Configurando o frame de cima
# Demarcação de pontos do jogador

# A demarcação do 'X' do resultado
appX = Label(frame_cima, text='X', height=1, relief='flat',
             anchor='center', font=('Ivy 40 bold'), bg=co1, fg=co7)
appX.place(x=20, y=10)

# A demarcação da laber de 'Jogador 1'
appX = Label(frame_cima, text='Jogador 1', height=1, relief='flat',
             anchor='center', font=('Ivy 7 bold'), bg=co1, fg=co0)
appX.place(x=15, y=70)

# A demarcação da pontuação
appXpontos = Label(frame_cima, text='0', height=1, relief='flat',
                   anchor='center', font=('Ivy 30 bold'), bg=co1, fg=co0)
appXpontos.place(x=75, y=20)

# %%
# Separador de pontos-----------------------------------------------------------------------------------------------

appSeparador = Label(frame_cima, text=':', height=1, relief='flat',
                     anchor='center', font=('Ivy 30 bold'), bg=co1, fg=co0)
appSeparador.place(x=105, y=17)

# %%
# Demarcação de pontos do jogador Y-----------------------------------------------------------------------------------------------

# A demarcação do 'O' do resultado
appO = Label(frame_cima, text='O', height=1, relief='flat',
             anchor='center', font=('Ivy 40 bold'), bg=co1, fg=co4)
appO.place(x=175, y=10)

# A demarcação da laber de 'Jogador 2'
appO = Label(frame_cima, text='Jogador 2', height=1, relief='flat',
             anchor='center', font=('Ivy 7 bold'), bg=co1, fg=co0)
appO.place(x=175, y=70)

# A demarcação da pontuação
appOpontos = Label(frame_cima, text='0', height=1, relief='flat',
                   anchor='center', font=('Ivy 30 bold'), bg=co1, fg=co0)
appOpontos.place(x=130, y=20)

# %%
# Criando lógica do app-----------------------------------------------------------------------------------------------

jogador1 = 'X'
jogador2 = 'O'

score1 = 0
score2 = 0

tabela = [['1', '2', '3'], ['4', '5', '6'], ['7', '8', '9']]

jogando = 'X'
jogar = ''
contador = 0
contadorDeRodadas = 0

# %%
def iniciarJogo():
    
    # Para controlar o jogo
    def controlar(i):

        # variáveis globais
        global jogando
        global contador
        global jogar

        # Cada quadrante do jogo recebe um valor e ao ser clicado transfere para as variáveis
        if i == str(1):

            # Verificando se a posição está vazia ou não:
            if botao1['text'] == '':

                # Verificando quem está jogando e definir a cor do símbolo
                if jogando == 'X':
                    cor = co7
                if jogando == 'O':
                    cor = co4

                # Definindo a cor do texto do botão e marcar a
                # posição da tabela com o valor do
                # jogador atual

                botao1['fg'] = cor
                botao1['text'] = jogando
                tabela[0][0] = jogando

                # Verificando quem está jogando, para poder trocar de jogar

                if jogando == 'X':
                    jogando = 'O'
                    joga = 'Jogador 1'

                else:
                    jogando = 'X'
                    joga = 'Jogador 2'

                # Incrementar o contador para próxima rodada:
                contador += 1

                # Caso o contador >= 5, deverá verificar na tabela se houve Match em algum padrão:

                if contador >= 5:
                    # linhas
                    if tabela[0][0] == tabela[0][1] == tabela[0][2] != '':
                        vencedor(jogando)

                    elif tabela[1][0] == tabela[1][1] == tabela[1][2] != '':
                        vencedor(jogando)

                    elif tabela[2][0] == tabela[2][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    # colunas
                    if tabela[0][0] == tabela[1][0] == tabela[2][0] != '':
                        vencedor(jogando)

                    elif tabela[0][1] == tabela[1][1] == tabela[2][1] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][2] == tabela[2][2] != '':
                        vencedor(jogando)

                    # diagonais
                    if tabela[0][0] == tabela[1][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][1] == tabela[2][0] != '':
                        vencedor(jogando)

                    # empate

                    if contador >= 9:
                        vencedor('Empate!!!')

        if i == str(2):

            # Verificando se a posição está vazia ou não:
            if botao2['text'] == '':

                # Verificando quem está jogando e definir a cor do símbolo
                if jogando == 'X':
                    cor = co7
                if jogando == 'O':
                    cor = co4

                # Definindo a cor do texto do botão e marcar a
                # posição da tabela com o valor do
                # jogador atual

                botao2['fg'] = cor
                botao2['text'] = jogando
                tabela[0][1] = jogando

                # Verificando quem está jogando, para poder trocar de jogar

                if jogando == 'X':
                    jogando = 'O'
                    joga = 'Jogador 1'

                else:
                    jogando = 'X'
                    joga = 'Jogador 2'

                # Incrementar o contador para próxima rodada:
                contador += 1

                # Caso o contador >= 5, deverá verificar na tabela se houve Match em algum padrão:

                if contador >= 5:
                    # linhas
                    if tabela[0][0] == tabela[0][1] == tabela[0][2] != '':
                        vencedor(jogando)

                    elif tabela[1][0] == tabela[1][1] == tabela[1][2] != '':
                        vencedor(jogando)

                    elif tabela[2][0] == tabela[2][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    # colunas
                    if tabela[0][0] == tabela[1][0] == tabela[2][0] != '':
                        vencedor(jogando)

                    elif tabela[0][1] == tabela[1][1] == tabela[2][1] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][2] == tabela[2][2] != '':
                        vencedor(jogando)

                    # diagonais
                    if tabela[0][0] == tabela[1][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][1] == tabela[2][0] != '':
                        vencedor(jogando)

                    # empate

                    if contador >= 9:
                        vencedor('Empate!!!')

        if i == str(3):

            # Verificando se a posição está vazia ou não:
            if botao3['text'] == '':

                # Verificando quem está jogando e definir a cor do símbolo
                if jogando == 'X':
                    cor = co7
                if jogando == 'O':
                    cor = co4

                # Definindo a cor do texto do botão e marcar a
                # posição da tabela com o valor do
                # jogador atual

                botao3['fg'] = cor
                botao3['text'] = jogando
                tabela[0][2] = jogando

                # Verificando quem está jogando, para poder trocar de jogar

                if jogando == 'X':
                    jogando = 'O'
                    joga = 'Jogador 1'

                else:
                    jogando = 'X'
                    joga = 'Jogador 2'

                # Incrementar o contador para próxima rodada:
                contador += 1

                # Caso o contador >= 5, deverá verificar na tabela se houve Match em algum padrão:

                if contador >= 5:
                    # linhas
                    if tabela[0][0] == tabela[0][1] == tabela[0][2] != '':
                        vencedor(jogando)

                    elif tabela[1][0] == tabela[1][1] == tabela[1][2] != '':
                        vencedor(jogando)

                    elif tabela[2][0] == tabela[2][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    # colunas
                    if tabela[0][0] == tabela[1][0] == tabela[2][0] != '':
                        vencedor(jogando)

                    elif tabela[0][1] == tabela[1][1] == tabela[2][1] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][2] == tabela[2][2] != '':
                        vencedor(jogando)

                    # diagonais
                    if tabela[0][0] == tabela[1][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][1] == tabela[2][0] != '':
                        vencedor(jogando)

                    # empate

                    if contador >= 9:
                        vencedor('Empate!!!')

        if i == str(4):

            # Verificando se a posição está vazia ou não:
            if botao4['text'] == '':

                # Verificando quem está jogando e definir a cor do símbolo
                if jogando == 'X':
                    cor = co7
                if jogando == 'O':
                    cor = co4

                # Definindo a cor do texto do botão e marcar a
                # posição da tabela com o valor do
                # jogador atual

                botao4['fg'] = cor
                botao4['text'] = jogando
                tabela[1][0] = jogando

                # Verificando quem está jogando, para poder trocar de jogar

                if jogando == 'X':
                    jogando = 'O'
                    joga = 'Jogador 1'

                else:
                    jogando = 'X'
                    joga = 'Jogador 2'

                # Incrementar o contador para próxima rodada:
                contador += 1

                # Caso o contador >= 5, deverá verificar na tabela se houve Match em algum padrão:

                if contador >= 5:
                    # linhas
                    if tabela[0][0] == tabela[0][1] == tabela[0][2] != '':
                        vencedor(jogando)

                    elif tabela[1][0] == tabela[1][1] == tabela[1][2] != '':
                        vencedor(jogando)

                    elif tabela[2][0] == tabela[2][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    # colunas
                    if tabela[0][0] == tabela[1][0] == tabela[2][0] != '':
                        vencedor(jogando)

                    elif tabela[0][1] == tabela[1][1] == tabela[2][1] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][2] == tabela[2][2] != '':
                        vencedor(jogando)

                    # diagonais
                    if tabela[0][0] == tabela[1][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][1] == tabela[2][0] != '':
                        vencedor(jogando)

                    # empate

                    if contador >= 9:
                        vencedor('Empate!!!')

        if i == str(5):

            # Verificando se a posição está vazia ou não:
            if botao5['text'] == '':

                # Verificando quem está jogando e definir a cor do símbolo
                if jogando == 'X':
                    cor = co7
                if jogando == 'O':
                    cor = co4

                # Definindo a cor do texto do botão e marcar a
                # posição da tabela com o valor do
                # jogador atual

                botao5['fg'] = cor
                botao5['text'] = jogando
                tabela[1][1] = jogando

                # Verificando quem está jogando, para poder trocar de jogar

                if jogando == 'X':
                    jogando = 'O'
                    joga = 'Jogador 1'

                else:
                    jogando = 'X'
                    joga = 'Jogador 2'

                # Incrementar o contador para próxima rodada:
                contador += 1

                # Caso o contador >= 5, deverá verificar na tabela se houve Match em algum padrão:

                if contador >= 5:
                    # linhas
                    if tabela[0][0] == tabela[0][1] == tabela[0][2] != '':
                        vencedor(jogando)

                    elif tabela[1][0] == tabela[1][1] == tabela[1][2] != '':
                        vencedor(jogando)

                    elif tabela[2][0] == tabela[2][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    # colunas
                    if tabela[0][0] == tabela[1][0] == tabela[2][0] != '':
                        vencedor(jogando)

                    elif tabela[0][1] == tabela[1][1] == tabela[2][1] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][2] == tabela[2][2] != '':
                        vencedor(jogando)

                    # diagonais
                    if tabela[0][0] == tabela[1][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][1] == tabela[2][0] != '':
                        vencedor(jogando)

                    # empate

                    if contador >= 9:
                        vencedor('Empate!!!')

        if i == str(6):

            # Verificando se a posição está vazia ou não:
            if botao6['text'] == '':

                # Verificando quem está jogando e definir a cor do símbolo
                if jogando == 'X':
                    cor = co7
                if jogando == 'O':
                    cor = co4

                # Definindo a cor do texto do botão e marcar a
                # posição da tabela com o valor do
                # jogador atual

                botao6['fg'] = cor
                botao6['text'] = jogando
                tabela[1][2] = jogando

                # Verificando quem está jogando, para poder trocar de jogar

                if jogando == 'X':
                    jogando = 'O'
                    joga = 'Jogador 1'

                else:
                    jogando = 'X'
                    joga = 'Jogador 2'

                # Incrementar o contador para próxima rodada:
                contador += 1

                # Caso o contador >= 5, deverá verificar na tabela se houve Match em algum padrão:

                if contador >= 5:
                    # linhas
                    if tabela[0][0] == tabela[0][1] == tabela[0][2] != '':
                        vencedor(jogando)

                    elif tabela[1][0] == tabela[1][1] == tabela[1][2] != '':
                        vencedor(jogando)

                    elif tabela[2][0] == tabela[2][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    # colunas
                    if tabela[0][0] == tabela[1][0] == tabela[2][0] != '':
                        vencedor(jogando)

                    elif tabela[0][1] == tabela[1][1] == tabela[2][1] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][2] == tabela[2][2] != '':
                        vencedor(jogando)

                    # diagonais
                    if tabela[0][0] == tabela[1][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][1] == tabela[2][0] != '':
                        vencedor(jogando)

                    # empate

                    if contador >= 9:
                        vencedor('Empate!!!')

        if i == str(7):

            # Verificando se a posição está vazia ou não:
            if botao7['text'] == '':

                # Verificando quem está jogando e definir a cor do símbolo
                if jogando == 'X':
                    cor = co7
                if jogando == 'O':
                    cor = co4

                # Definindo a cor do texto do botão e marcar a
                # posição da tabela com o valor do
                # jogador atual

                botao7['fg'] = cor
                botao7['text'] = jogando
                tabela[2][0] = jogando

                # Verificando quem está jogando, para poder trocar de jogar

                if jogando == 'X':
                    jogando = 'O'
                    joga = 'Jogador 1'

                else:
                    jogando = 'X'
                    joga = 'Jogador 2'

                # Incrementar o contador para próxima rodada:
                contador += 1

                # Caso o contador >= 5, deverá verificar na tabela se houve Match em algum padrão:

                if contador >= 5:
                    # linhas
                    if tabela[0][0] == tabela[0][1] == tabela[0][2] != '':
                        vencedor(jogando)

                    elif tabela[1][0] == tabela[1][1] == tabela[1][2] != '':
                        vencedor(jogando)

                    elif tabela[2][0] == tabela[2][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    # colunas
                    if tabela[0][0] == tabela[1][0] == tabela[2][0] != '':
                        vencedor(jogando)

                    elif tabela[0][1] == tabela[1][1] == tabela[2][1] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][2] == tabela[2][2] != '':
                        vencedor(jogando)

                    # diagonais
                    if tabela[0][0] == tabela[1][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][1] == tabela[2][0] != '':
                        vencedor(jogando)

                    # empate

                    if contador >= 9:
                        vencedor('Empate!!!')

        if i == str(8):

            # Verificando se a posição está vazia ou não:
            if botao8['text'] == '':

                # Verificando quem está jogando e definir a cor do símbolo
                if jogando == 'X':
                    cor = co7
                if jogando == 'O':
                    cor = co4

                # Definindo a cor do texto do botão e marcar a
                # posição da tabela com o valor do
                # jogador atual

                botao8['fg'] = cor
                botao8['text'] = jogando
                tabela[2][1] = jogando

                # Verificando quem está jogando, para poder trocar de jogar

                if jogando == 'X':
                    jogando = 'O'
                    joga = 'Jogador 1'

                else:
                    jogando = 'X'
                    joga = 'Jogador 2'

                # Incrementar o contador para próxima rodada:
                contador += 1

                # Caso o contador >= 5, deverá verificar na tabela se houve Match em algum padrão:

                if contador >= 5:
                    # linhas
                    if tabela[0][0] == tabela[0][1] == tabela[0][2] != '':
                        vencedor(jogando)

                    elif tabela[1][0] == tabela[1][1] == tabela[1][2] != '':
                        vencedor(jogando)

                    elif tabela[2][0] == tabela[2][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    # colunas
                    if tabela[0][0] == tabela[1][0] == tabela[2][0] != '':
                        vencedor(jogando)

                    elif tabela[0][1] == tabela[1][1] == tabela[2][1] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][2] == tabela[2][2] != '':
                        vencedor(jogando)

                    # diagonais
                    if tabela[0][0] == tabela[1][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][1] == tabela[2][0] != '':
                        vencedor(jogando)

                    # empate

                    if contador >= 9:
                        vencedor('Empate!!!')

        if i == str(9):

            # Verificando se a posição está vazia ou não:
            if botao9['text'] == '':

                # Verificando quem está jogando e definir a cor do símbolo
                if jogando == 'X':
                    cor = co7
                if jogando == 'O':
                    cor = co4

                # Definindo a cor do texto do botão e marcar a
                # posição da tabela com o valor do
                # jogador atual

                botao9['fg'] = cor
                botao9['text'] = jogando
                tabela[2][2] = jogando

                # Verificando quem está jogando, para poder trocar de jogar

                if jogando == 'X':
                    jogando = 'O'
                    joga = 'Jogador 1'

                else:
                    jogando = 'X'
                    joga = 'Jogador 2'

                # Incrementar o contador para próxima rodada:
                contador += 1

                # Caso o contador >= 5, deverá verificar na tabela se houve Match em algum padrão:

                if contador >= 5:
                    # linhas
                    if tabela[0][0] == tabela[0][1] == tabela[0][2] != '':
                        vencedor(jogando)

                    elif tabela[1][0] == tabela[1][1] == tabela[1][2] != '':
                        vencedor(jogando)

                    elif tabela[2][0] == tabela[2][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    # colunas
                    if tabela[0][0] == tabela[1][0] == tabela[2][0] != '':
                        vencedor(jogando)

                    elif tabela[0][1] == tabela[1][1] == tabela[2][1] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][2] == tabela[2][2] != '':
                        vencedor(jogando)

                    # diagonais
                    if tabela[0][0] == tabela[1][1] == tabela[2][2] != '':
                        vencedor(jogando)

                    elif tabela[0][2] == tabela[1][1] == tabela[2][0] != '':
                        vencedor(jogando)

                    # empate

                    if contador >= 9:
                        vencedor('Empate!!!')

        print(i)

    # Decidir o vencedor
    def vencedor(i):
        
        global tabela
        global score1
        global score2
        global contadorDeRodadas
        global contador

       
        #Assim que o jogo terminar, os botões serão desabilitados
        botao1['state'] = 'disable'
        botao2['state'] = 'disable'
        botao3['state'] = 'disable'
        botao4['state'] = 'disable'
        botao5['state'] = 'disable'
        botao6['state'] = 'disable'
        botao7['state'] = 'disable'
        botao8['state'] = 'disable'
        botao9['state'] = 'disable'
        
        appVencedor = Label(frame_baixo, text='', width=17, relief='flat',
                            anchor='center', font=('Ivy 13 bold'), bg=co1, fg=co2)
        appVencedor.place(x=40, y=200)

        if i == 'X':
            score2 += 1
            appVencedor['text'] = 'Jogador 2 venceu!'
            appOpontos['text'] = score2

        elif i == 'O':
            score1 += 1
            appVencedor['text'] = 'Jogador 1 venceu!'
            appXpontos['text'] = score1

        elif i == 'Empate!!!':
            appVencedor['text'] = 'Empate!!!'
        
        
        #Assim que a rodada terminar, irá destruir os botões(X e O)
        def start():
            # limpando os botões
            botao1['text'] = ''
            botao2['text'] = ''
            botao3['text'] = ''
            botao4['text'] = ''
            botao5['text'] = ''
            botao6['text'] = ''
            botao7['text'] = ''
            botao8['text'] = ''
            botao9['text'] = ''
            
            # limpando os botões
            botao1['state'] = 'normal'
            botao2['state'] = 'normal'
            botao3['state'] = 'normal'
            botao4['state'] = 'normal'
            botao5['state'] = 'normal'
            botao6['state'] = 'normal'
            botao7['state'] = 'normal'
            botao8['state'] = 'normal'
            botao9['state'] = 'normal'
            
            #Elimina os labels
            appVencedor.destroy()
            botaoJogar.destroy()
            
        # Botão Jogar --------------------------------------------------------------------
        botaoJogar = Button(frame_baixo, command = start, text = 'Próxima rodada', width = 17, font = (
        'Ivy 10 bold'), overrelief = RIDGE, relief = 'raised', bg = fundo, fg = co0)

        botaoJogar.place(x = 51, y = 250)
        
        
        def gameOver():
        
            botaoJogar.destroy()
            appVencedor.destroy()
            
            terminarAtual()

            
        if contadorDeRodadas >= 5:
            gameOver()
            
        else:
            contadorDeRodadas += 1
            #Reiniciando a tabela
            tabela = [['1', '2', '3'], ['4', '5', '6'], ['7', '8', '9']]
            contador = 0
            
            
            
    # Terminar o jogo atual
    def terminarAtual():
        
        global tabela
        global contadorDeRodadas
        global score1
        global score2
        global contador
        
        tabela = [['1', '2', '3'], ['4', '5', '6'], ['7', '8', '9']]
        contadorDeRodadas = 0
        score1 = 0 
        score2 = 0
        contador = 0
        
        #Assim que o jogo terminar, os botões serão desabilitados
        botao1['state'] = 'disable'
        botao2['state'] = 'disable'
        botao3['state'] = 'disable'
        botao4['state'] = 'disable'
        botao5['state'] = 'disable'
        botao6['state'] = 'disable'
        botao7['state'] = 'disable'
        botao8['state'] = 'disable'
        botao9['state'] = 'disable'        


        appFim = Label(frame_baixo, text='Fim de Jogo!', width=17, relief='flat',
                            anchor='center', font=('Ivy 13 bold'), bg=co1, fg=co2)
        appFim.place(x=30, y=200)
 
        #Jogar de Novo
    
    
    def jogarDeNovo():
        
        appOpontos['text'] = '0'
        appXpontos['text'] = '0'
        appFim.destroy()
        botaoJogar.destroy()
        
        #Chamando a função iniciar de novo:
        iniciarJogo()
        
    # Botão Jogar de Novo --------------------------------------------------------------------
    botaoJogar = Button(frame_baixo, command = jogarDeNovo, text = 'Jogar de Novo', height = 1, font = (
    'Ivy 10 bold'), overrelief = RIDGE, relief = 'raised', bg = fundo, fg = co0)

    botaoJogar.place(x = 70, y = 250)        

        
        
        
    # Configurando o frame de baixo--------------------------------------------------------------------

    # Linahs Divisórias verticais
    divisoriaVert1 = Label(frame_baixo, text='', height=23, relief='flat',
                           pady=5, anchor='center', font=('Ivy 5 bold'), bg=co0, fg=co4)
    divisoriaVert1.place(x=85, y=0)

    divisoriaVert2 = Label(frame_baixo, text='', height=23, relief='flat',
                           pady=5, anchor='center', font=('Ivy 5 bold'), bg=co0, fg=co4)
    divisoriaVert2.place(x=151, y=0)

    # Linhas de Divisórias horizontais
    divisoriaHor1 = Label(frame_baixo, text=' ', width=182, relief='flat',
                          pady=1, padx=2, anchor='center', font=('Ivy 1 bold'), bg=co0, fg=co4)
    divisoriaHor1.place(x=25, y=56)

    divisoriaHor2 = Label(frame_baixo, text=' ', width=182, relief='flat',
                          pady=1, padx=2, anchor='center', font=('Ivy 1 bold'), bg=co0, fg=co4)
    divisoriaHor2.place(x=25, y=116)

    # Configurando as visualizações de botações --------------------------------------------------------------------
    # Parâmetros:

    # frame_baixo >>> Indica que o botão está localizado no frame de baixo, definido suas dimensões (240 x300)
    # command = lambda: controlar('') >>> Indica o comando dado ao botão para acionar a 'Function' 'Controlar()'__
    # O lambda foi necessário para passar um valor como argumento para a function

    # Primeira linha
    botao1 = Button(frame_baixo, command=lambda: controlar('1'), text='', width=3, font=(
        'Ivy 20 bold'), overrelief=RIDGE, relief='flat', bg=fundo, fg=co7)
    botao1.place(x=25, y=0)

    botao2 = Button(frame_baixo, command=lambda: controlar('2'), text='', width=3, font=(
        'Ivy 20 bold'), overrelief=RIDGE, relief='flat', bg=fundo, fg=co7)
    botao2.place(x=90, y=0)

    botao3 = Button(frame_baixo, command=lambda: controlar('3'), text='', width=3, font=(
        'Ivy 20 bold'), overrelief=RIDGE,  relief='flat', bg=fundo, fg=co7)
    botao3.place(x=155, y=0)

    # Segunda linha
    botao4 = Button(frame_baixo, command=lambda: controlar('4'), text='', width=3, font=(
        'Ivy 20 bold'), overrelief=RIDGE, relief='flat', bg=fundo, fg=co7)
    botao4.place(x=25, y=60)

    botao5 = Button(frame_baixo, command=lambda: controlar('5'), text='', width=3, font=(
        'Ivy 20 bold'), overrelief=RIDGE, relief='flat', bg=fundo, fg=co7)
    botao5.place(x=90, y=60)

    botao6 = Button(frame_baixo, command=lambda: controlar('6'), text='', width=3, font=(
        'Ivy 20 bold'), overrelief=RIDGE, relief='flat', bg=fundo, fg=co7)
    botao6.place(x=155, y=60)

    # Terceira linha
    botao7 = Button(frame_baixo, command=lambda: controlar('7'), text='', width=3, font=(
        'Ivy 20 bold'), overrelief=RIDGE, relief='flat', bg=fundo, fg=co7)
    botao7.place(x=25, y=120)

    botao8 = Button(frame_baixo, command=lambda: controlar('8'), text='', width=3, font=(
        'Ivy 20 bold'), overrelief=RIDGE, relief='flat', bg=fundo, fg=co7)
    botao8.place(x=90, y=120)

    botao9 = Button(frame_baixo, command=lambda: controlar('9'), text='', width=3, font=(
        'Ivy 20 bold'), overrelief=RIDGE, relief='flat', bg=fundo, fg=co7)
    botao9.place(x=155, y=120)

# %%
# Botão Jogar --------------------------------------------------------------------
botaoJogar = Button(frame_baixo, command= iniciarJogo, text='Jogar', width=10, font=(
    'Ivy 10 bold'), overrelief=RIDGE, relief='raised', bg=fundo, fg=co0)
botaoJogar.place(x=76, y=250)

# %%
# Exibir a janela
janela.mainloop()
# Out:
# 1
# 9
# 5
# 6
# 3
# 8
# 7
